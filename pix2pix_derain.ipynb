# %% [markdown]
# <a href="https://colab.research.google.com/github/vfrantc/qderain/blob/main/pix2pix_derain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2443, done.
# remote: Total 2443 (delta 0), reused 0 (delta 0), pack-reused 2443
# Receiving objects: 100% (2443/2443), 8.18 MiB | 27.46 MiB/s, done.
# Resolving deltas: 100% (1532/1532), done.

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix')

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 676 kB 12.0 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 60.5 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 142 kB 81.4 MB/s
# ...
#      |████████████████████████████████| 97 kB 8.9 MB/s
# ...
#      |████████████████████████████████| 180 kB 77.2 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.5 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=1882fbdfb6fb2151482093a8b33b1715f4b7ff6f6ea10b3c5d5562bd945fde55
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=131ed9677e52aecbf4a27f6c6bc67129bfdbc4d3be213e46b33e4c10401e2f2d
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...

# %%
from google.colab import drive

# %%
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !cp drive/MyDrive/derain/derain200h.zip datasets/

# %%
# %cd datasets/
# Out:
# /content/pytorch-CycleGAN-and-pix2pix/datasets

# %%
# !unzip derain200h.zip
# Out:
# Archive:  derain200h.zip
#    creating: derain200h/
#    creating: derain200h/test/
#   inflating: derain200h/test/81.png
#   inflating: derain200h/test/83.png
#   inflating: derain200h/test/70.png
#   inflating: derain200h/test/73.png
#   inflating: derain200h/test/1.png
#   inflating: derain200h/test/57.png
#   inflating: derain200h/test/27.png
#   inflating: derain200h/test/87.png
#   inflating: derain200h/test/8.png
#   inflating: derain200h/test/49.png
#   inflating: derain200h/test/66.png
#   inflating: derain200h/test/37.png
#   inflating: derain200h/test/32.png
#   inflating: derain200h/test/63.png
#   inflating: derain200h/test/5.png
#   inflating: derain200h/test/4.png
#   inflating: derain200h/test/36.png
#   inflating: derain200h/test/35.png
#   inflating: derain200h/test/6.png
#   inflating: derain200h/test/58.png
#   inflating: derain200h/test/3.png
#   inflating: derain200h/test/80.png
#   inflating: derain200h/test/19.png
#   inflating: derain200h/test/21.png
# ...

# %%
# %cd ..
# Out:
# /content/pytorch-CycleGAN-and-pix2pix

# %%
# !python train.py --dataroot ./datasets/derain200h/ --name derain200h --model pix2pix --direction AtoB --use_wandb
# Out:
# Streaming output truncated to the last 5000 lines.
# (epoch: 26, iters: 900, time: 0.068, data: 0.002) G_GAN: 3.719 G_L1: 10.064 D_real: 0.000 D_fake: 0.510
# (epoch: 26, iters: 1000, time: 0.348, data: 0.002) G_GAN: 4.013 G_L1: 14.216 D_real: 0.109 D_fake: 0.012
# (epoch: 26, iters: 1100, time: 0.065, data: 0.002) G_GAN: 0.818 G_L1: 9.958 D_real: 2.684 D_fake: 0.177
# (epoch: 26, iters: 1200, time: 0.068, data: 0.002) G_GAN: 4.796 G_L1: 8.075 D_real: 0.001 D_fake: 0.012
# (epoch: 26, iters: 1300, time: 0.062, data: 0.003) G_GAN: 4.801 G_L1: 8.126 D_real: 0.021 D_fake: 0.016
# (epoch: 26, iters: 1400, time: 0.204, data: 0.004) G_GAN: 3.263 G_L1: 10.378 D_real: 0.130 D_fake: 0.060
# (epoch: 26, iters: 1500, time: 0.068, data: 0.005) G_GAN: 3.739 G_L1: 11.918 D_real: 0.006 D_fake: 0.045
# (epoch: 26, iters: 1600, time: 0.064, data: 0.003) G_GAN: 5.771 G_L1: 10.370 D_real: 0.002 D_fake: 0.004
# ...

# %%
# !ls
# Out:
# checkpoints	docs		 LICENSE	README.md	  train.py
# CycleGAN.ipynb	drive		 models		requirements.txt  util
# data		environment.yml  options	scripts		  wandb
# datasets	imgs		 pix2pix.ipynb	test.py

# %%
# !ls checkpoints
# Out:
# derain200h

# %%
# !cp -r checkpoints drive/MyDrive/derain
